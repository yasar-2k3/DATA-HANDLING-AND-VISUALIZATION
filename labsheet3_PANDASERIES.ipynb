# %%
import pandas as pd
s1=pd.Series([-3,-1,1,3,5 ,'gaurav',7.3])
print(s1)
# Out:
# 0        -3
# 1        -1
# 2         1
# 3         3
# 4         5
# 5    gaurav
# 6       7.3
# dtype: object

# %%
print(s1[2])
# Out:
# 1

# %%
a=[1,7,2]
myvar=pd.Series (a,index=['x','y','z'])
print(myvar)
print(myvar ["y"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 7

# %%
calories={"day 1":420,"day 2":345,"day 3":390}
myvar=pd.Series(calories)

# %%
print(s1[[2,1,0]])
# Out:
# 2     1
# 1    -1
# 0    -3
# dtype: object

# %%
type(s1)
# Out:
# pandas.core.series.Series

# %%
s=pd.Series([1,2,3,4,5],index=['a','b','c','d','e'])
print(s[['a','c','d']])
# Out:
# a    1
# c    3
# d    4
# dtype: int64

# %%
data={
    "calories":[420,345,390],
    "duration":[50,40,45]
}
df=pd.DataFrame(data)
print(df)
# Out:
#    calories  duration
# 0       420        50
# 1       345        40
# 2       390        45

# %%
import pandas as pd
data={'Name':['tom','jack','steve','ricky'],'Age':[28,34,29,42]}
df=pd.DataFrame(data,index=['rank 1','rank 2','rank 3','rank 4'])

# %%
print(df)
# Out:
#          Name  Age
# rank 1    tom   28
# rank 2   jack   34
# rank 3  steve   29
# rank 4  ricky   42

# %%
print(calories["day 2"])
# Out:
# 345
