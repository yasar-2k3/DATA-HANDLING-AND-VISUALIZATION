# %%
import pandas as pd
import numpy as np
from functools import reduce

# %%
df = pd.read_csv("/content/drive/MyDrive/Dataset/BL-Flickr-Images-Book.csv")
print(df.head())
# Out:
#    Identifier             Edition Statement      Place of Publication  \
# 0         206                           NaN                    London
# 1         216                           NaN  London; Virtue & Yorston
# 2         218                           NaN                    London
# 3         472                           NaN                    London
# 4         480  A new edition, revised, etc.                    London
#
#   Date of Publication              Publisher  \
# 0         1879 [1878]       S. Tinsley & Co.
# 1                1868           Virtue & Co.
# 2                1869  Bradbury, Evans & Co.
# 3                1851          James Darling
# 4                1857   Wertheim & Macintosh
#
#                                                Title     Author  \
# 0                  Walter Forbes. [A novel.] By A. A      A. A.
# 1  All for Greed. [A novel. The dedication signed...  A., A. A.
# 2  Love the Avenger. By the author of “All for Gr...  A., A. A.
# ...

# %%
for col in df.columns:
  print(col)
# Out:
# Identifier
# Edition Statement
# Place of Publication
# Date of Publication
# Publisher
# Title
# Author
# Contributors
# Corporate Author
# Corporate Contributors
# Former owner
# Engraver
# Issuance type
# Flickr URL
# Shelfmarks

# %%
to_drop=["Shelfmarks","Place of Publication","Title","Corporate Author","Engraver",
         "Former owner"]
df.drop(to_drop,inplace=True,axis=1)
df.head()
# Out:
#    Identifier             Edition Statement Date of Publication  \
# 0         206                           NaN         1879 [1878]
# 1         216                           NaN                1868
# 2         218                           NaN                1869
# 3         472                           NaN                1851
# 4         480  A new edition, revised, etc.                1857
#
#                Publisher     Author  \
# 0       S. Tinsley & Co.      A. A.
# 1           Virtue & Co.  A., A. A.
# 2  Bradbury, Evans & Co.  A., A. A.
# 3          James Darling  A., E. S.
# 4   Wertheim & Macintosh  A., E. S.
#
#                                    Contributors  Corporate Contributors  \
# 0                               FORBES, Walter.                     NaN
# 1  BLAZE DE BURY, Marie Pauline Rose - Baroness                     NaN
# 2  BLAZE DE BURY, Marie Pauline Rose - Baroness                     NaN
# ...

# %%
df.set_index("Identifier",inplace=True)
df.head()
# Out:
#                        Edition Statement Date of Publication  \
# Identifier
# 206                                  NaN         1879 [1878]
# 216                                  NaN                1868
# 218                                  NaN                1869
# 472                                  NaN                1851
# 480         A new edition, revised, etc.                1857
#
#                         Publisher     Author  \
# Identifier
# 206              S. Tinsley & Co.      A. A.
# 216                  Virtue & Co.  A., A. A.
# 218         Bradbury, Evans & Co.  A., A. A.
# 472                 James Darling  A., E. S.
# 480          Wertheim & Macintosh  A., E. S.
#
#                                             Contributors  \
# Identifier
# 206                                      FORBES, Walter.
# 216         BLAZE DE BURY, Marie Pauline Rose - Baroness
# 218         BLAZE DE BURY, Marie Pauline Rose - Baroness
# ...

# %%
unwanted_characters=['[',',','-']
def clean_data(item):
  dop=str(item.loc['Date of Publication'])
  if dop=='nan' or dop[0]=='[':
    return np.NaN
    for character in unwanted_character:
      if character in dop:
        character_index=dop.find(character)
        dop=dop[:character_index]
        return dop

# %%
df['Date of Pubilication']=df.apply(clean_data,axis=1)

# %%
df['Date of Pubilication'].head(25)
# Out:
# Identifier
# 206    NaN
# 216    NaN
# 218    NaN
# 472    NaN
# 480    NaN
# 481    NaN
# 519    NaN
# 667    NaN
# 874    NaN
# 1143   NaN
# 1280   NaN
# 1808   NaN
# 1905   NaN
# 1929   NaN
# 2836   NaN
# 2854   NaN
# 2956   NaN
# 2957   NaN
# 3017   NaN
# 3131   NaN
# 4598   NaN
# 4884   NaN
# 4976   NaN
# 5382   NaN
# 5385   NaN
# Name: Date of Pubilication, dtype: float64

# %%
def clean_title(title):
  if title=='nan':
    return 'NaN'
  if title[0]=='[':
    title=title[1:title.find(']')]
  if 'by'in title:
    title =title[:title.find('by')]
  elif 'By'in title:
      title=title[:title.find('By')]
  if'[' in title:
    title=title[:title.find('[')]
    title=title[:-2]
    df['title']=df['title'].apply(clean_title)
    df.head()

# %%
df.loc[4159587]
df.head(20)
# Out:
#                                             Edition Statement  \
# Identifier
# 206                                                       NaN
# 216                                                       NaN
# 218                                                       NaN
# 472                                                       NaN
# 480                              A new edition, revised, etc.
# 481                             Fourth edition, revised, etc.
# 519                                                       NaN
# 667                                                       NaN
# 874                                                       NaN
# 1143                                                      NaN
# 1280                                                      NaN
# 1808                                                      NaN
# 1905                                                      NaN
# 1929                                                      NaN
# ...
